# %% [markdown]
# # Pandas basics

# %%
# !ls

# we use exclamation point (!) in the jup_notebook to run command lines
# Out:
# __MACOSX
# 01-pandas basics.ipynb
# continent_facts.csv
# countries.csv

# %% [markdown]
# # Let's install pandas

# %%
# !pip install --quiet pandas

# only run this once
# Out:
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Requests

import requests

# %%
# Importing pandas

import pandas as pd

# everyone does import pd

# %%
# pd.read_csv("countries.csv")

# this is called a dataframe
# lets save as a df

df = pd.read_csv("countries.csv")

# %%
# to print a df just type \df\

# %%
# Let's look at the first 5
df.head ()
# Out:
#                country   continent  life_expectancy  population           gdp
# 0          Afghanistan        Asia           54.863    22856302   15153728226
# 1              Albania      Europe           74.200     3071856   12886435920
# 2              Algeria      Africa           68.963    30533827  155661450046
# 3               Angola      Africa           45.234    13926373   34063908358
# 4  Antigua and Barbuda  N. America           73.544       77656     989182128

# %%
# Show me the last five 
# the opposite of head is tail 

df.tail()
# Out:
#                 country continent  life_expectancy  population           gdp
# 183             Vietnam      Asia           73.777    78758010  124201381770
# 184  West Bank and Gaza      Asia           70.929     3198560   24264276160
# 185         Yemen, Rep.      Asia           60.404    17723186   39292303362
# 186              Zambia    Africa           41.802    10201562   10558616670
# 187            Zimbabwe    Africa           43.976    12509477    9319560365

# %%
# To get help in documentation: shift + TAB

# %%
# Try to get the life expectancy
# for every single country

# df.get(['life_expectancy']) -> Iv'e tried this one first, but actually its:

# %%
df.sort_values('life_expectancy')
# Out:
#                   country continent  life_expectancy  population  \
# 147          Sierra Leone    Africa           38.123     4143115
# 186                Zambia    Africa           41.802    10201562
# 31   Central African Rep.    Africa           43.727     3701607
# 187              Zimbabwe    Africa           43.976    12509477
# 3                  Angola    Africa           45.234    13926373
# ..                    ...       ...              ...         ...
# 160                Sweden    Europe           79.840     8860153
# 7               Australia   Oceania           79.930    19164351
# 161           Switzerland    Europe           79.990     7167908
# 72       Hong Kong, China      Asia           80.361     6783317
# 83                  Japan      Asia           81.350   125720310
#
#                gdp
# 147     2141990455
# 186    10558616670
# 31      2820624534
# 187     9319560365
# 3      34063908358
# ..             ...
# 160   253754781920
# 7     560384787591
# ...

# %%
df.sort_values('life_expectancy', ascending=False)
# Out:
#                   country continent  life_expectancy  population  \
# 83                  Japan      Asia           81.350   125720310
# 72       Hong Kong, China      Asia           80.361     6783317
# 161           Switzerland    Europe           79.990     7167908
# 7               Australia   Oceania           79.930    19164351
# 160                Sweden    Europe           79.840     8860153
# ..                    ...       ...              ...         ...
# 3                  Angola    Africa           45.234    13926373
# 187              Zimbabwe    Africa           43.976    12509477
# 31   Central African Rep.    Africa           43.727     3701607
# 186                Zambia    Africa           41.802    10201562
# 147          Sierra Leone    Africa           38.123     4143115
#
#                gdp
# 83   3590446333290
# 72    203309577124
# 161   246475684488
# 7     560384787591
# 160   253754781920
# ..             ...
# 3      34063908358
# 187     9319560365
# ...

# %%
# IF you only want 2 columns from the df:

df[['country','life_expectancy']]
# Out:
#                  country  life_expectancy
# 0            Afghanistan           54.863
# 1                Albania           74.200
# 2                Algeria           68.963
# 3                 Angola           45.234
# 4    Antigua and Barbuda           73.544
# ..                   ...              ...
# 183              Vietnam           73.777
# 184   West Bank and Gaza           70.929
# 185          Yemen, Rep.           60.404
# 186               Zambia           41.802
# 187             Zimbabwe           43.976
#
# [188 rows x 2 columns]

# %%
# If we want the top 10 life-expect countries:

df.sort_values('life_expectancy', ascending=False).head(10)
# Out:
#               country   continent  life_expectancy  population            gdp
# 83              Japan        Asia           81.350   125720310  3590446333290
# 72   Hong Kong, China        Asia           80.361     6783317   203309577124
# 161       Switzerland      Europe           79.990     7167908   246475684488
# 7           Australia     Oceania           79.930    19164351   560384787591
# 160            Sweden      Europe           79.840     8860153   253754781920
# 81              Italy      Europe           79.730    56986329  1547748695640
# 74            Iceland      Europe           79.720      281210     8743381320
# 29             Canada  N. America           79.410    30667365   995094659520
# 155             Spain      Europe           79.340    40288457   943152778370
# 57             France      Europe           79.230    59047795  1690892657620

# %%
# Filter things that are in continent Asia

df['continent']=='Asia'

df[df['continent']=='Asia']
# Out:
#                   country continent  life_expectancy  population  \
# 0             Afghanistan      Asia           54.863    22856302
# 11                Bahrain      Asia           74.497      638193
# 12             Bangladesh      Asia           65.309   129592275
# 18                 Bhutan      Asia           60.307      571262
# 23                 Brunei      Asia           75.927      327036
# 27               Cambodia      Asia           62.030    12446949
# 34                  China      Asia           72.124  1269116737
# 72       Hong Kong, China      Asia           80.361     6783317
# 75                  India      Asia           62.129  1053898107
# 76              Indonesia      Asia           67.289   213395411
# 77                   Iran      Asia           69.611    65342319
# 78                   Iraq      Asia           70.845    23857458
# 80                 Israel      Asia           78.750     6014953
# ...

# %%
# Entry every country of Asia that life expectancy > 75

# df['continent'] == 'Asia'
# df['life_expectancy'] > 75
#we will have to this: (wraping in parenthesis

# (df['continent'] == 'Asia') & (df['life_expectancy'] > 75)

# and then:


df[(df['continent'] == 'Asia') & (df['life_expectancy'] > 75)]
# Out:
#               country continent  life_expectancy  population            gdp
# 23             Brunei      Asia           75.927      327036    15704268720
# 72   Hong Kong, China      Asia           80.361     6783317   203309577124
# 80             Israel      Asia           78.750     6014953   137345436802
# 83              Japan      Asia           81.350   125720310  3590446333290
# 89        Korea, Rep.      Asia           76.114    45987624   781559669880
# 100      Macao, China      Asia           77.627      431867     9722189904
# 135             Qatar      Asia           76.680      590957    35690257058
# 148         Singapore      Asia           78.340     3919300   144363496200
# 163            Taiwan      Asia           76.020    22183000   521855075000

# %%
# This is a lot easier to read and understand, but no one does it:

df.query('life_expectancy > 75 and continent == "Asia"')
# Out:
#               country continent  life_expectancy  population            gdp
# 23             Brunei      Asia           75.927      327036    15704268720
# 72   Hong Kong, China      Asia           80.361     6783317   203309577124
# 80             Israel      Asia           78.750     6014953   137345436802
# 83              Japan      Asia           81.350   125720310  3590446333290
# 89        Korea, Rep.      Asia           76.114    45987624   781559669880
# 100      Macao, China      Asia           77.627      431867     9722189904
# 135             Qatar      Asia           76.680      590957    35690257058
# 148         Singapore      Asia           78.340     3919300   144363496200
# 163            Taiwan      Asia           76.020    22183000   521855075000

# %%
# If I want to check Portugal:

df[df['country'] == 'Portugal']
# Out:
#       country continent  life_expectancy  population           gdp
# 134  Portugal    Europe            76.84    10336209  202682722281

# %%
df['life_expectancy']
# Out:
# 0      54.863
# 1      74.200
# 2      68.963
# 3      45.234
# 4      73.544
#         ...
# 183    73.777
# 184    70.929
# 185    60.404
# 186    41.802
# 187    43.976
# Name: life_expectancy, Length: 188, dtype: float64

# %%
df['life_expectancy'].mean() # média
# Out:
# np.float64(66.50153603526596)

# %%
df['life_expectancy'].median() # mediana
# Out:
# np.float64(70.04150000000001)

# %%
df['gdp'].sum()
# Out:
# np.int64(48316204002444)

# %%
# You can just do this:

# %%
df['life_expectancy'].describe()
# Out:
# count    188.000000
# mean      66.501536
# std       10.298458
# min       38.123000
# 25%       59.663750
# 50%       70.041500
# 75%       74.134500
# max       81.350000
# Name: life_expectancy, dtype: float64

# %%
#correlation

df[['life_expectancy', 'gdp']].corr()

# But this aient fair
# Out:
#                  life_expectancy       gdp
# life_expectancy         1.000000  0.209858
# gdp                     0.209858  1.000000

# %%
# calculate the per capita gdp
# gdp / population

per_cap = df['gdp'] / df['population']
per_cap

# This is ok, but you can save it as column
# Out:
# 0        663.0
# 1       4195.0
# 2       5098.0
# 3       2446.0
# 4      12738.0
#         ...
# 183     1577.0
# 184     7586.0
# 185     2217.0
# 186     1035.0
# 187      745.0
# Length: 188, dtype: float64

# %%
# Creating and saving it

df['gdp_per_cap'] = df['gdp'] / df['population'] # this is how you add new column
df
# Out:
#                  country   continent  life_expectancy  population  \
# 0            Afghanistan        Asia           54.863    22856302
# 1                Albania      Europe           74.200     3071856
# 2                Algeria      Africa           68.963    30533827
# 3                 Angola      Africa           45.234    13926373
# 4    Antigua and Barbuda  N. America           73.544       77656
# ..                   ...         ...              ...         ...
# 183              Vietnam        Asia           73.777    78758010
# 184   West Bank and Gaza        Asia           70.929     3198560
# 185          Yemen, Rep.        Asia           60.404    17723186
# 186               Zambia      Africa           41.802    10201562
# 187             Zimbabwe      Africa           43.976    12509477
#
#               gdp  gdp_per_cap
# 0     15153728226        663.0
# 1     12886435920       4195.0
# 2    155661450046       5098.0
# 3     34063908358       2446.0
# ...

# %%
# Step 1: df
# Step 2 : filters
# Step 3: groupby
# Step 4: column(s)
# Step 5: the math

df.groupby('continent')['life_expectancy'].median()
# Out:
# continent
# Africa        52.1025
# Asia          70.4275
# Europe        75.5800
# N. America    70.5765
# Oceania       67.4955
# S. America    70.7660
# Name: life_expectancy, dtype: float64

# %%
# Continent Europe_

europe = df[df['continent'] == "Europe"] 
europe.head(4)
# Out:
#       country continent  life_expectancy  population           gdp  \
# 1     Albania    Europe           74.200     3071856   12886435920
# 6     Armenia    Europe           71.494     3076098    6502871172
# 8     Austria    Europe           78.330     8004712  256214821696
# 9  Azerbaijan    Europe           66.851     8110723   20544461359
#
#    gdp_per_cap
# 1       4195.0
# 6       2114.0
# 8      32008.0
# 9       2533.0

# %%
# Lets mess it up

europe['population'] = 0
europe

# The warning message isn't really worring
# be aware that single equal sign is dangerouuus
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17436\1548081192.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   europe['population'] = 0
#                     country continent  life_expectancy  population  \
# 1                   Albania    Europe        74.200000           0
# 6                   Armenia    Europe        71.494000           0
# 8                   Austria    Europe        78.330000           0
# 9                Azerbaijan    Europe        66.851000           0
# 14                  Belarus    Europe        68.990000           0
# 15                  Belgium    Europe        77.910000           0
# 20   Bosnia and Herzegovina    Europe        74.882000           0
# ...

# %%
# How many countries are in each country?

df['continent'].value_counts()
# Out:
# continent
# Africa        54
# Asia          48
# Europe        42
# N. America    22
# S. America    12
# Oceania       10
# Name: count, dtype: int64

# %% [markdown]
# ## Can we read stuff from the internet?

# %%
# Oh YES WE CAN

url = "https://www.theguardian.com/football/laligafootball/table"
pd.read_html(url)
# Out:
# [     P            Team  GP   W   D   L   F   A  GD  Pts  \
#  0    1        Atlético  25  15   8   2  40  16  24   53
#  1    2       Barcelona  24  16   3   5  65  25  40   51
#  2    3     Real Madrid  24  15   6   3  52  23  29   51
#  3    4        A Bilbao  24  12   9   3  37  21  16   45
#  4    5      Villarreal  25  12   8   5  48  35  13   44
#  5    6  Rayo Vallecano  25   9   8   8  27  26   1   35
#  6    7        Mallorca  24  10   4  10  23  30  -7   34
#  7    8      Real Betis  24   8   8   8  30  31  -1   32
#  8    9      Celta Vigo  25   9   5  11  36  38  -2   32
#  9   10         Osasuna  25   7  11   7  29  34  -5   32
#  10  11          Girona  24   9   4  11  32  35  -3   31
#  11  12   Real Sociedad  24   9   4  11  20  23  -3   31
#  12  13         Sevilla  24   8   7   9  29  34  -5   31
#  13  14          Getafe  24   7   9   8  20  18   2   30
#  14  15        Espanyol  25   7   6  12  24  36 -12   27
# ...

# %%
# Lets transform it... I guess?

tables = pd.read_html(url)
len(tables)
# Out:
# 1

# %%
tables[0]
# Out:
#      P            Team  GP   W   D   L   F   A  GD  Pts  \
# 0    1        Atlético  25  15   8   2  40  16  24   53
# 1    2       Barcelona  24  16   3   5  65  25  40   51
# 2    3     Real Madrid  24  15   6   3  52  23  29   51
# 3    4        A Bilbao  24  12   9   3  37  21  16   45
# 4    5      Villarreal  25  12   8   5  48  35  13   44
# 5    6  Rayo Vallecano  25   9   8   8  27  26   1   35
# 6    7        Mallorca  24  10   4  10  23  30  -7   34
# 7    8      Real Betis  24   8   8   8  30  31  -1   32
# 8    9      Celta Vigo  25   9   5  11  36  38  -2   32
# 9   10         Osasuna  25   7  11   7  29  34  -5   32
# 10  11          Girona  24   9   4  11  32  35  -3   31
# 11  12   Real Sociedad  24   9   4  11  20  23  -3   31
# 12  13         Sevilla  24   8   7   9  29  34  -5   31
# 13  14          Getafe  24   7   9   8  20  18   2   30
# 14  15        Espanyol  25   7   6  12  24  36 -12   27
# 15  16         Leganes  24   5   9  10  22  35 -13   24
# ...

# %%
# Since its a df now you just save it

df = tables[0]
df
# Out:
#      P            Team  GP   W   D   L   F   A  GD  Pts  \
# 0    1        Atlético  25  15   8   2  40  16  24   53
# 1    2       Barcelona  24  16   3   5  65  25  40   51
# 2    3     Real Madrid  24  15   6   3  52  23  29   51
# 3    4        A Bilbao  24  12   9   3  37  21  16   45
# 4    5      Villarreal  25  12   8   5  48  35  13   44
# 5    6  Rayo Vallecano  25   9   8   8  27  26   1   35
# 6    7        Mallorca  24  10   4  10  23  30  -7   34
# 7    8      Real Betis  24   8   8   8  30  31  -1   32
# 8    9      Celta Vigo  25   9   5  11  36  38  -2   32
# 9   10         Osasuna  25   7  11   7  29  34  -5   32
# 10  11          Girona  24   9   4  11  32  35  -3   31
# 11  12   Real Sociedad  24   9   4  11  20  23  -3   31
# 12  13         Sevilla  24   8   7   9  29  34  -5   31
# 13  14          Getafe  24   7   9   8  20  18   2   30
# 14  15        Espanyol  25   7   6  12  24  36 -12   27
# 15  16         Leganes  24   5   9  10  22  35 -13   24
# ...

# %%
# What if we want to share this beautiful df with someone?


# df.to_csv("laliga.csv") 
# Yeah, sure but it saves the index and we dont want that

df.to_csv("laliga.csv", index= False)

# ALWAYS DO: index=False

# %%
# Panda can create a dataframe for you easily

pd.DataFrame(data['something']['something2'])

# but if there are a lot of dictionaries inside of dictionaries there is a solution:
pd.json_normalize(data['something']['something2'])
